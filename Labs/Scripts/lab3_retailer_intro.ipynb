# %% [markdown]
# # IS 4487 Lab 3
#
# ## Outline
#
# Repeat exercises from Lab 2, but with the *SuperStore Retail Orders* dataset
# - Loading installed packages
# - Inspect data
# - Explore plot types
#
# <a href="https://colab.research.google.com/github/Stan-Pugsley/is_4487_base/blob/main/Labs/Scripts/lab3_retailer_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Load Libraries
#
# ➡️ Assignment Tasks
# - Load any necessary libraries

# %%
import pandas as pd
import matplotlib as mpl
import sklearn as sl

# %% [markdown]
# ## Import Data into Dataframe
#
# ➡️ Assignment Tasks
# - Import data from the SuperStore retail dataset into a dataframe (in GitHub go to Labs > DataSets)
# - Describe or profile the dataframe

# %%
df = pd.read_csv('superstore_retail_orders.csv')
df.describe()
# Out:
#            order_id       quantity  product_price
# count  56043.000000   56004.000000   56043.000000
# mean   61668.410578       3.348582    6198.309433
# std     7508.142486     422.654112   35784.965255
# min    45079.000000       1.000000       2.290000
# 25%    55644.500000       1.000000       7.950000
# 50%    61870.000000       1.000000     475.600000
# 75%    68097.000000       2.000000     914.620000
# max    74147.000000  100000.000000  235481.000000

# %% [markdown]
# ## Prepare Data
#
# ➡️ Assignment Tasks
# - Convert the Total_Amount into a number (not a string)
# - Remove rows with empty (NULL) values
# - Optional: Locate outliers in any of the variables.   Filter them out if they are mistakes; keep them if they are exceptional cases.

# %%
# Add column 'Total_Amount' equal to float value of quantity * price.
df['Total_Amount'] = (df['quantity'] * df['product_price'])

# Drop empty (NULL) rows from dataframe.
df.dropna(inplace=True)
# Out:
#            order_id       quantity  product_price  Total_Amount
# count  55498.000000   55498.000000   55498.000000  5.549800e+04
# mean   61674.114202       3.365184    6228.292227  1.195330e+04
# std     7502.275744     424.576497   35876.722587  7.496301e+04
# min    45079.000000       1.000000       2.290000  2.290000e+00
# 25%    55659.000000       1.000000       7.950000  1.497000e+01
# 50%    61885.500000       1.000000     475.600000  4.756000e+02
# 75%    68088.750000       2.000000     914.620000  1.219260e+03
# max    74147.000000  100000.000000  235481.000000  2.024994e+06

# %% [markdown]
# ## Summarize Data
#
# ➡️ Assignment Tasks
# - Display the average price per month
# - Display the total revenue for all months

# %%
#average price per month
df['month'] = df['order_year_month'].str[-2:]
df[['product_price','month']].groupby('month').mean().round(2)
# Out:
#        product_price
# month
# 01           6168.88
# 02           6407.83
# 03           5570.46
# 04           6126.99
# 05           6717.55
# 06           6582.89
# 07           3912.52
# 08           6331.74
# 09           6841.40
# 10           6431.14
# 11           6589.59
# 12           5722.03

# %%
#total revenue
